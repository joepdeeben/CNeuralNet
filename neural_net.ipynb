# %%
import numpy as np


vals = np.array([1, 2, 4])
depth = 3
width = 3

W = []
b = []

for i in range(depth):
    W.append(np.random.randn(width, 3))   
    b.append(np.random.randn(width))  

W.append(np.random.randn(1, 3))   
b.append(np.random.randn(1))

print(W)
# Out:
# [array([[ 0.6363538 , -0.72078559,  1.13100474],
#        [-0.31562507,  0.71000149, -0.30176396],
#        [ 0.80291002, -0.35901067, -1.75675376]]), array([[ 0.43577487, -0.11749648,  0.35971524],
#        [-0.16337474, -1.31288373,  0.36804015],
#        [ 0.04302879,  2.01165822, -0.59133267]]), array([[ 0.11675063, -1.7654679 ,  0.22096377],
#        [ 1.41062401, -3.46085073, -0.44130148],
#        [-0.31880413, -0.40773646,  0.34076199]]), array([[ 0.4323469 ,  0.28749626, -0.28236278]])]

# %%
def forward(values, weights, bias):
    for w, b in zip(weights, bias):
        values = w @ values + b 
        values[values < 0] = 0
        print(values)

forward(vals)

def backpropagate()
# Out:
# [ 2.38802786  0.20384846 -6.0648244 ]
# [ 0.13487951 -3.22900018  4.14858994]
# [ 7.85277645 10.2651341   3.32972405]
# [6.34662082]
